# %% [markdown]
# # Initial Demo

# %%
# resolve project root and add to path for imports in notebooks
import sys
from pathlib import Path

# Get the absolute path to the project root (e.g., one level up)
project_root = str(Path().resolve().parent)

if project_root not in sys.path:
    sys.path.insert(0, project_root)

print("Project root:", project_root)
# Out:
# Project root: C:\Users\goetschm\CodingProj\coco-caption-generator

# %% [markdown]
# ## Image Preprocessing (Extract Features)

# %%
from src.data.extract_features import main as extract_features

extract_features()

# %% [markdown]
# ## Text Preprocessing (Build Vocabulary)

# %%
from src.data.preprocess import main as preprocess_captions

preprocess_captions()

# %% [markdown]
# ## Single Forward Pass Through Model

# %%
from src.data.vocab import Vocabulary
from src.models.model import ImageCaptionModel
from src.utils.config import VOCAB_FILE, VOCAB_MIN_FREQ, FEATURES_FILE
import torch

# Example usage of the model
vocab = Vocabulary(min_freq=VOCAB_MIN_FREQ)
vocab.load(VOCAB_FILE)
model = ImageCaptionModel(vocab_size=len(vocab))
print("Model initialized with vocabulary size:", len(vocab))

# EXAMPLE_IMAGE_PATH = "data/raw/images/000000000885.jpg"
features = torch.load(FEATURES_FILE)
image_features = features[0]  # Assuming the first image's features for testing

model.generate_caption(image_features, vocab)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 8
#       4 import torch
#       5
#       6 # Example usage of the model
#       7 vocab = Vocabulary(min_freq=VOCAB_MIN_FREQ)
# ----> 8 vocab.load(VOCAB_FILE)
#       9 model = ImageCaptionModel(vocab_size=len(vocab))
#      10 print("Model initialized with vocabulary size:", len(vocab))
#      11
#
# File ~\CodingProj\coco-caption-generator\src\data\vocab.py:50, in Vocabulary.load(cls, path)
#      48 @classmethod
#      49 def load(cls, path: str) -> "Vocabulary":
# ---> 50     with open(path) as f:
#      51         data = json.load(f)
#      52     vocab = cls(min_freq=data["min_freq"])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/processed/vocab.json'
